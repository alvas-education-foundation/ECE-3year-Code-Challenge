# %% [markdown]
# <a href="https://colab.research.google.com/github/alvas-education-foundation/ECE-3year-Code-Challenge/blob/master/YalpiNandika_4AL17EC096.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code Challenge
Ua_Try=0
while Ua_Try<3:
    Login_Name=input("Enter the LoginName: ")
    Password=input("Enter thePassword: ")
    if Login_Name=="Micheal" and Password =="e3$WT89x":
        print("You are Logged in!")
        break;
    else:
        Ua_Try+=1
        print("Invalid Credentials Please Try Again!")
print("Account Locked")
