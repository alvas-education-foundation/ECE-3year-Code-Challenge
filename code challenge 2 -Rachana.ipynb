# %%
import pandas as pd
from matplotlib import pyplot

import matplotlib.pyplot as plt
data = pd.read_csv("/home/envisionlab/Downloads/file1.csv")

# %%
data.head()
# Out:
#     Time  Raw_ECG
# 0  18000      -12
# 1  18001      -17
# 2  18002      -17
# 3  18003      -17
# 4  18004      -18

# %%
max(data['Time'])
# Out:
# 23899

# %%
min(data['Time'])
# Out:
# 18000

# %%
data.shape
# Out:
# (5900, 2)

# %%
data['Time'].plot()

# %%
data['Raw_ECG'].plot()

# %%
data['Time'].plot()
data['Raw_ECG'].plot()

# %%
a = data.iloc[1:,:1]
print(a)
# Out:
#        Time
# 1     18001
# 2     18002
# 3     18003
# 4     18004
# 5     18005
# ...     ...
# 5895  23895
# 5896  23896
# 5897  23897
# 5898  23898
# 5899  23899
#
# [5899 rows x 1 columns]

# %%
b = data.iloc[1:,1]
print(b)
# Out:
# 1      -17
# 2      -17
# 3      -17
# 4      -18
# 5      -29
#         ..
# 5895    -1
# 5896    -2
# 5897    -4
# 5898    -5
# 5899    -7
# Name: Raw_ECG, Length: 5899, dtype: int64

# %%
from scipy import signal

# %%
import matplotlib.pyplot as plt

# %%
b, a = signal.butter(4, 100, 'low', analog=True)

# %%
 w, h = signal.freqs(b, a)

# %%
import numpy as np
plt.plot(w, 20 * np.log10(abs(h)))

# %%
plt.xscale('log')
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(100, color='green') 
plt.show()
plt.plot(w, 20 * np.log10(abs(h)))

# %%
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
data1 = pd.read_csv("/home/envisionlab/Downloads/file3.csv")

# %%
data1
# Out:
#       18000  Raw_ECG  Low pass  high pass   der-filter       square
# 0     18000      -17  0.891975  -0.029514  71.20601953  8.438365928
# 1     18001      -17  0.891975  -0.029514  150.4059481  12.26401028
# 2     18002      -17  0.891975  -0.029514  200.8059317  14.17060097
# 3     18003      -17  0.891975  -0.029514  200.8059317  14.17060097
# 4     18004      -18  0.897507  -0.029605  174.6056122  13.21384169
# ...     ...      ...       ...        ...          ...          ...
# 5895  23895       -1  0.000000   1.000000          NaN          NaN
# 5896  23896       -2  0.430664  -0.020818          NaN          NaN
# 5897  23897       -4  0.639688  -0.025000          NaN          NaN
# 5898  23898       -5  0.694356  -0.026042          NaN          NaN
# 5899  23899       -7  0.765612  -0.027344          NaN          NaN
#
# [5900 rows x 6 columns]

# %%
data1.describe()
# Out:
#               18000      Raw_ECG     Low pass    high pass
# count   5900.000000  5900.000000  5734.000000  5734.000000
# mean   20949.500000    -0.098814     0.977187    -0.017128
# std     1703.327626    56.389852     0.373577     0.117979
# min    18000.000000  -234.000000     0.000000    -0.062485
# 25%    19474.750000   -20.000000     0.862245    -0.031994
# 50%    20949.500000    -7.000000     0.942042    -0.030331
# 75%    22424.250000    15.000000     1.048186    -0.029018
# max    23899.000000   369.000000     3.875977     1.000000

# %%
data1['Low pass'].plot()

# %%
data1['high pass'].plot()

# %%
data1['Low pass'].plot()
data1['high pass'].plot()

# %%
data1['square'].value_counts().plot(kind = 'line',title = 'GRADE ANALYSIS OF PHYSICS ', alpha= 0.80,grid = True)

plt.show()

# %%
from sympy import fft

seq = [12.26401028,
14.17060097,
14.17060097,
13.21384169,
15.40141195,
11.64507473,
19.53980226,
83.78905218,
113.1945358,
13.85663385,
64.81750023,
44.26646592,
27.84582577,
12.0366137,
13.37145804,
14.95313818,
14.26144937,
9.8221741,
15.77047026,
8.056292673,
6.340567077,
10.54050799,
7.943700029,
0.839298379,
5.585903492,
2.52950333,
6.212925968,
9.418062949,
4.950011995,
10.09953313,
8.717845227,
16.49548944,
9.929890696,
11.84071156,
13.74416892,
7.943700029,
5.079721629,
2.665112839,
1.950745666,
6.481125571,
8.983488191,
11.67109073,
7.141810148,
6.620691814,
6.957025702,
5.787159729,
11.17120109,
1.816691401,
6.595255329,
3.331351263,
9.455063834,
4.194945702,
8.757711208,
8.485156168,
8.068228668,
5.839043268,
10.17305297,
11.73403482,
12.53409394,
13.91941276,
5.357519141,
10.6444555,
3.50791339,
9.46705398,
8.741002663,
2.685581069,
1.41615292,
13.17967224,
13.18347082,
1.551141778,
16.70645358,
15.70997024,
7.341857824,
2.53013092,
60.99920084,
104.0177979,
63.8639613,
27.76693995,
57.54309982,
32.57376259,
12.9653407,
3.75952494,
6.25275488,
12.75917282,
3.91018968,
3.052095299,
0.44721359,
4.970183797,
14.83962031,
5.890851958,
14.69360559,
3.808511308,
7.218911901,
14.89293562,
18.91559481,
18.27018163,
20.33964503] 
   
transform = fft(seq) 
print (transform)
# Out:
# [1474.76545990200, -59.75133198*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32) - 44.17164178*sqrt(sqrt(2)/4 + 1/2)*cos(pi/32)*cos(pi/16) - 36.01813553*sqrt(sqrt(2)/4 + 1/2)*cos(pi/16) - 17.62062441*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32)*cos(pi/16) - 15.73032625*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/16) - 10.507386781*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/32) - 9.713384894*sqrt(2)*sqrt(sqrt(2)/4 + 1/2) - 7.718928995*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/16) - 7.547691724*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64) - 6.8528314865*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/32)*cos(pi/16) - 5.620873085*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32)*cos(pi/16) - 4.984964343*sqrt(2)*cos(pi/64)*cos(pi/32)*cos(pi/16) - 4.4489129245*sqrt(2)*cos(pi/64)*cos(pi/32) - 4.1549305595*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/64)*cos(pi/32) - 9.7644822005*sqrt(2)*sqrt(1/2 - sqrt(2)/4)*cos(pi/64)*cos(pi/32) - 3.8132095235*sqrt(2)*sqrt(sqrt(2)/4 + 1/2)*cos(pi/16) - 11.67109073*sqrt(1/2 - sqrt(2)/4)
# ...

# %%
 fourier values cannot be plots i gave try .
